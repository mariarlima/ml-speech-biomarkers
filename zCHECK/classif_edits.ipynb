# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.preprocessing import StandardScaler

from mlcog import evaluation, models as m
from mlcog import tuning, bootstrap, evaluation 
from mlcog.utils import io

# %% [markdown]
# #### *Lexical and semantic psycholinguistic features*

# %%
ling_train = pd.read_pickle('../data/features/ling_train.pkl')
ling_train.head()
# Out:
#    pid  label                                               data
# 0  267      0  [81, 58.92, 54.78, 83.36, 20.23, 4.26, 8.64, 9...
# 1  273      0  [110, 80.0, 71.57, 20.79, 47.86, 10.0, 13.64, ...
# 2  298      0  [92, 84.34, 93.93, 44.75, 35.66, 7.08, 14.13, ...
# 3  307      0  [83, 56.34, 74.41, 13.52, 76.34, 7.55, 7.23, 7...
# 4  312      0  [128, 64.33, 75.49, 48.9, 30.91, 5.82, 11.72, ...

# %%
ling_train.data[0].shape
# Out:
# (100,)

# %%
X_train = np.stack(ling_train['data'].values)   
y = ling_train['label'].values

# %%
from mlcog.utils.io import get_cv_model_path
print(get_cv_model_path("cv_ling", "lr").resolve())
# Out:
# /Users/marialima/Desktop/GitHub-ML-cog-code/data/cv_eval/cv_ling/10fcv_lr.pkl

# %%
models = m.create_models()
param_grids = m.create_param_grids()

# model selection and crossvalidation
results_ling = []
for name, model in models.items():
    result = tuning.crossval(name, model, param_grids[name], X_train, y, feature_set = 'cv_ling')
    results_ling.append(result)

df_eval_cv_ling = pd.DataFrame(results_ling)
df_eval_cv_ling
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
#      Model  Sensitivity  Specificity      Roc_auc     Accuracy
# 0       lr  72.8 (19.1)  72.0 (18.7)  74.8 (15.9)  72.2 (13.9)
# 1      svm  78.5 (18.2)  64.5 (16.7)  75.1 (15.2)  71.7 (12.8)
# 2       rf  76.1 (14.4)  70.7 (15.2)   79.0 (8.8)  73.4 (11.3)
# 3       nn  63.2 (12.9)  72.1 (10.9)   74.8 (8.7)   67.4 (7.3)
# 4  xgboost   77.9 (9.9)  75.0 (18.5)  78.9 (12.4)   76.4 (8.7)

# %%
# PATH_SAVE_DF = "../data/cv_eval/cv_ling/"
# df_eval_cv_ling.to_csv(PATH_SAVE_DF + "classif_results.csv", index=False)

# %% [markdown]
# #### Evaluation on unseen test set

# %%
ling_test = pd.read_pickle('../data/features/ling_test.pkl')
ling_test.head()
# Out:
#   pid  label                                               data
# 0  58      0  [57, 47.02, 94.48, 1.0, 5.65, 8.14, 14.04, 89....
# 1  64      1  [57, 62.72, 70.59, 14.46, 74.93, 5.7, 15.79, 9...
# 2  70      1  [62, 95.94, 97.31, 25.64, 6.37, 4.43, 6.45, 95...
# 3  71      1  [156, 1.0, 99.0, 1.31, 49.66, 19.5, 13.46, 97....
# 4  65      0  [107, 88.19, 94.26, 10.52, 48.73, 15.29, 12.15...

# %%
model_map_class = {
        'Logistic Regression': 'lr',
        'SVM': 'svm',
        'Random Forest': 'rf',
        'Neural Network': 'nn',
        'XGBoost': 'xgboost',
    }
prefix = "10fcv_"
best_hyperparams = io.load_best_params(model_map_class, feature_set = 'cv_ling')
best_hyperparams['Random Forest']
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('clf',
#                  RandomForestClassifier(max_depth=17, min_samples_leaf=2,
#                                         min_samples_split=3, n_estimators=50,
#                                         random_state=42))])

# %%
X_test  = np.stack(ling_test['data'].values)
y_test  = ling_test['label'].values

evaluation_bootstrap, probs = bootstrap.fit_and_evaluate_bootstrap_classification(
    best_hyperparams, 
    X_train, 
    y, 
    X_test, 
    y_test
)
evaluation_bootstrap_df = pd.DataFrame(evaluation_bootstrap)
df = evaluation_bootstrap_df.round(3)
df[df.columns[1:]] = df[df.columns[1:]] * 100

results_dict = {}
for model_name in df.Model:
    results = evaluation.extract_results_classif_test(df[df.Model == model_name])
    results_dict[model_name] = results
results_dict
# Out:
# {'Logistic Regression': ('70.6 (68.0 - 73.1)',
#   '89.4 (87.2 - 91.7)',
#   '88.2 (86.7 - 89.7)',
#   '80.1 (78.8 - 81.5)'),
#  'SVM': ('76.0 (65.4 - 86.6)',
#   '77.5 (61.4 - 93.6)',
#   '88.8 (87.3 - 90.3)',
#   '76.8 (71.9 - 81.6)'),
#  'Random Forest': ('69.1 (64.2 - 74.0)',
#   '81.4 (78.3 - 84.5)',
#   '84.2 (82.3 - 86.1)',
#   '75.4 (72.7 - 78.0)'),
#  'Neural Network': ('70.3 (65.1 - 75.5)',
#   '78.1 (73.3 - 82.8)',
#   '83.4 (80.5 - 86.3)',
#   '74.2 (70.0 - 78.4)'),
#  'XGBoost': ('72.0 (67.2 - 76.8)',
#   '83.3 (80.5 - 86.1)',
#   '85.6 (84.0 - 87.1)',
#   '77.7 (75.2 - 80.3)')}

# %% [markdown]
# ### RF-NLP: external & pilot evaluation

# %% [markdown]
# ___

# %% [markdown]
# Replicating old version in paper

# %%
ling_train = pd.read_pickle('../data/features/ling_train.pkl')

X = ling_train['data']
y = ling_train['label']
X_train_2d = np.stack(X.values)
# Normalization
scaler = StandardScaler()
X_scaled_train = scaler.fit_transform(X_train_2d)


# NOTE: changed crossvalidation() to save in new folder
models = m.create_models()
param_grids = m.create_param_grids_()

# model selection and crossvalidation
results = []
for name, model in models.items():
    result = tuning.crossval_(name, model, param_grids[name], X_scaled_train, y, feature_set = 'cv_ling_REPLICATE')
    results.append(result)

df_eval_cv = pd.DataFrame(results)
df_eval_cv
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
#      Model  Sensitivity  Specificity      Roc_auc    Accuracy
# 0       lr  70.4 (10.0)   77.3 (9.2)   78.6 (6.0)  73.6 (6.5)
# 1      svm  75.0 (14.5)  69.5 (14.3)   78.1 (5.2)  72.2 (8.6)
# 2       rf  78.6 (14.3)  73.4 (15.3)   83.3 (7.7)  76.0 (9.0)
# 3       nn  69.4 (18.2)  70.7 (17.2)  73.4 (12.9)  69.9 (7.9)
# 4  xgboost  79.3 (10.9)  78.4 (18.7)   86.6 (8.9)  78.9 (8.7)

# %%
ling_test = pd.read_pickle('../data/features/ling_test.pkl')

X_test = ling_test['data']
y_test = ling_test['label']
X_test_2d = np.stack(X_test.values)

model_map_class = {
        'Logistic Regression': 'lr',
        'SVM': 'svm',
        'Random Forest': 'rf',
        'Neural Network': 'nn',
        'XGBoost': 'xgboost',
    }
best_hyperparams = io.load_best_params(model_map_class, feature_set = 'cv_ling_REPLICATE')
best_hyperparams['Random Forest']
# Out:
# RandomForestClassifier(max_depth=12, min_samples_leaf=3, random_state=42)

# %% [markdown]
# ___

# %%
X_test = ling_test['data']
y_test = ling_test['label']
X_test_2d = np.stack(X_test.values)

model_map_class = {
        'Logistic Regression': 'lr',
        'SVM': 'svm',
        'Random Forest': 'rf',
        'Neural Network': 'nn',
        'XGBoost': 'xgboost',
    }
prefix = "10fcv_"
best_hyperparams = io.load_best_params(model_map_class, prefix, feature_set = 'cv_ling')
best_hyperparams
# Out:
# {'Logistic Regression': LogisticRegression(C=np.float64(0.14024971326600363), max_iter=10000,
#                     penalty='l1', random_state=42, solver='liblinear'),
#  'SVM': SVC(C=np.float64(0.002460422958018418), gamma=np.float64(0.002154434690031882),
#      kernel='linear', probability=True, random_state=42),
#  'Random Forest': RandomForestClassifier(max_depth=12, min_samples_leaf=3, random_state=42),
#  'Neural Network': MLPClassifier(activation='logistic', alpha=np.float64(0.00016676611460145484),
#                batch_size=64, hidden_layer_sizes=(400,),
#                learning_rate='adaptive',
#                learning_rate_init=np.float64(0.0018595691547710724),
#                max_iter=10000, random_state=42, solver='sgd'),
#  'XGBoost': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=np.float64(0.7835939392709834), device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='logloss', feature_types=None, feature_weights=None,
#                gamma=np.float64(0.3633063543866615), grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=np.float64(0.1273853264268165), max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=2, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=102, n_jobs=None,
#                num_parallel_tree=None, ...)}

# %%
evaluation_bootstrap, probs = bootstrap.fit_and_evaluate_bootstrap_classification(
    best_hyperparams, 
    X_scaled_train, 
    y, 
    X_scaled_test, 
    y_test
)
evaluation_bootstrap_df = pd.DataFrame(evaluation_bootstrap)
df = evaluation_bootstrap_df.round(3)
df[df.columns[1:]] = df[df.columns[1:]] * 100
results_dict = {}
for model_name in df.Model:
    results = evaluation.extract_results_classif_test(df[df.Model == model_name])
    results_dict[model_name] = results
results_dict
# Out:
# {'Logistic Regression': ('74.9 (72.0 - 77.7)',
#   '85.0 (80.7 - 89.3)',
#   '87.0 (84.7 - 89.2)',
#   '80.0 (77.5 - 82.5)'),
#  'SVM': ('70.3 (63.8 - 76.8)',
#   '88.9 (86.2 - 91.5)',
#   '88.3 (86.5 - 90.1)',
#   '79.7 (77.1 - 82.3)'),
#  'Random Forest': ('70.0 (67.1 - 72.9)',
#   '85.8 (80.9 - 90.7)',
#   '86.0 (83.7 - 88.3)',
#   '78.0 (75.7 - 80.3)'),
#  'Neural Network': ('69.4 (64.0 - 74.9)',
#         0.79248016]),
#  array([0.39604762, 0.79133333, 0.56940476, 0.70725794, 0.23      ,
#         0.37459524, 0.59319048, 0.24287363, 0.65306133, 0.6555873 ,
#         0.46746429, 0.69228175, 0.55916955, 0.29161905, 0.74922222,
#         0.76526984, 0.74626984, 0.15160714, 0.3804881 , 0.39610498,
#         0.19940476, 0.87064286, 0.56195635, 0.82259524, 0.85702381,
#         0.36514286, 0.48586905, 0.48286905, 0.31704762, 0.74705556,
#         0.66069048, 0.17338095, 0.65383333, 0.49819336, 0.36264286,
#         0.67015476, 0.39741667, 0.31370238, 0.32957937, 0.34050458,
#         0.51442857, 0.58785714, 0.27330159, 0.96911172, 0.32353968,
#         0.30860775, 0.4071627 , 0.39398413, 0.36891667, 0.34184127,
#         0.72707143, 0.59038889, 0.16785714, 0.42383333, 0.85542918,
#         0.27873077, 0.441     , 0.73816667, 0.61453066, 0.81545238,
#         0.41674098, 0.36480159, 0.57859524, 0.54365873, 0.18065476,
#         0.06325458, 0.19834524, 0.60739971, 0.0928141 , 0.53896717,
#         0.86002778]),
#  array([0.37347619, 0.73698199, 0.6295    , 0.82859524, 0.28125   ,
#         0.48672222, 0.69264286, 0.31573016, 0.57063278, 0.72072802,
#         0.5062381 , 0.69689683, 0.63539469, 0.38642857, 0.82739286,
#         0.66732143, 0.70992857, 0.15158333, 0.55891056, 0.41180952,
#         0.29402778, 0.87109524, 0.3620119 , 0.86852381, 0.848     ,
#         0.37139286, 0.49758333, 0.39518651, 0.35025183, 0.56855952,
#         0.7700119 , 0.23784524, 0.71895238, 0.35111905, 0.43517857,
#         0.63988095, 0.40412698, 0.4432381 , 0.38669048, 0.28085714,
#         0.44372619, 0.69771429, 0.46223016, 0.94467857, 0.31345238,
#         0.3225754 , 0.4661627 , 0.42227961, 0.39921429, 0.50932326,
#         0.70283333, 0.45846429, 0.27183333, 0.39236905, 0.77083333,
#         0.41086905, 0.2505    , 0.78552564, 0.54380556, 0.92633333,
#         0.41136111, 0.46609921, 0.49169048, 0.54009524, 0.23313095,
#         0.14844048, 0.32070818, 0.59599098, 0.08475   , 0.49966558,
#         0.69733333])]

# %%
# # Save the probs dictionary as a pickle file
name = 'ling_probs_classif'
with open(f'../data/test_eval_probs/{name}.pkl', 'wb') as f:
    pickle.dump(probs, f)

# %% [markdown]
# ___

# %% [markdown]
# #### *GPT embeddings*

# %%
with open('../data/features/gpt_train.pkl', 'rb') as f:
    gpt_train = pickle.load(f)
gpt_train.head()
# Out:
# /var/folders/lm/sz7z6d6x725_9nyqv0hzt1jm0000gn/T/ipykernel_48363/1469547780.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   gpt_train = pickle.load(f)
#                                                 data  label  pid
# 0  [0.005286967847496271, 0.024346468970179558, -...      1  024
# 1  [0.022915663197636604, 0.011132195591926575, -...      1  025
# 2  [-0.0063759456388652325, 0.015673918649554253,...      1  027
# 3  [0.018051227554678917, -0.0007191338227130473,...      1  028
# 4  [0.023917796090245247, 0.04508865252137184, -0...      1  031

# %%
gpt_train.data[0].shape
# Out:
# (1536,)

# %%
X_gpt_train = np.stack(gpt_train['data'].values)   
y_gpt_train = gpt_train['label'].values

# %%
from mlcog.utils.io import get_cv_model_path
print(get_cv_model_path("cv_gpt", "lr").resolve())
# Out:
# /Users/marialima/Desktop/GitHub-ML-cog-code/data/cv_eval/cv_gpt/10fcv_lr.pkl

# %%
models = m.create_models()
param_grids = m.create_param_grids()

# model selection and crossvalidation
all_results_gpt = []
for name, model in models.items():
    result_gpt = tuning.crossval(name, model, param_grids[name], X_gpt_train, y_gpt_train, feature_set = 'cv_gpt')
    all_results_gpt.append(result_gpt)

df_eval_cv_gpt = pd.DataFrame(all_results_gpt)
df_eval_cv_gpt
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
#      Model  Sensitivity  Specificity     Roc_auc    Accuracy
# 0       lr  75.4 (16.0)  86.2 (11.8)  87.6 (5.7)  80.7 (8.8)
# 1      svm  79.2 (13.9)  82.5 (11.5)  87.1 (5.6)  80.7 (8.1)
# 2       rf  85.0 (12.9)  73.8 (19.7)  85.6 (7.5)  79.6 (9.1)
# 3       nn  75.7 (14.4)  79.8 (11.4)  88.7 (6.1)  77.7 (7.2)
# 4  xgboost  83.9 (12.0)  77.5 (15.6)  85.0 (7.8)  80.8 (9.7)

# %%
models = m.create_models()
param_grids = m.create_param_grids()

# model selection and crossvalidation
all_results_gpt = []
for name, model in models.items():
    result_gpt = tuning.crossval(name, model, param_grids[name], X_gpt_train, y_gpt_train, feature_set = 'cv_gpt')
    all_results_gpt.append(result_gpt)

df_eval_cv_gpt = pd.DataFrame(all_results_gpt)
df_eval_cv_gpt
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/marialima/Desktop/GitHub-ML-cog-code/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
#      Model  Sensitivity  Specificity      Roc_auc     Accuracy
# 0       lr  76.0 (12.0)  86.2 (13.1)   87.0 (8.2)  80.7 (10.7)
# 1      svm  78.3 (12.7)  81.2 (15.1)   86.3 (8.6)   79.5 (9.1)
# 2       rf   82.8 (9.4)  68.4 (17.8)   83.2 (9.7)  76.0 (10.7)
# 3       nn  79.3 (13.5)  76.2 (18.1)   87.5 (7.7)  77.7 (12.3)
# 4  xgboost   81.8 (9.0)  74.6 (17.7)  83.8 (10.9)  78.3 (11.4)

# %%
PATH_SAVE_DF = "../data/cv_eval/cv_gpt/"
df_eval_cv_gpt.to_csv(PATH_SAVE_DF + "classif_results.csv", index=False)

# %% [markdown]
# NOTE:
# - The same steps above can be applied to evaluate on unseen test set ```./data/features/gpt_test.pkl```
# - Similarly, these methods are applied to the external DementiaBank dataset and the pilot dataset
